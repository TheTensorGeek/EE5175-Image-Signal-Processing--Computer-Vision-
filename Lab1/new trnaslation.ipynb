# %%
import numpy as np 
from matplotlib import pyplot as plt 
import cv2
import imageio
import SimpleITK
import sys

# %%
cells = cv2.imread("cells_scale.png")
lina = cv2.imread("lena_translate.png",0)
src= cv2.imread("pisa_rotate.png",0)

# %%
from pylab import *
import cv2

#Bilinear function
def bilnr(src,theta, xn, yn) :
     #Mapping to src grid
    x = np.cos(theta)*xn - np.sin(theta)*yn
    y = np.sin(theta)*xn + np.cos(theta)*yn
    xf = int(np.floor(x)) +cenx
    yf = int(np.floor(y)) +ceny

    #distance from pixel
    a = x+cenx-xf
    b = y+ceny-yf

    #print(xf)

    #Calculate intensity
    if xf >= shape(src)[0]-1 or yf >=shape(src)[1]-1 or xf<=0 or yf<= 0 :
         Ival = 0
    else :
         Ival = (1-a)*(1-b)*src[xf][yf] + (1-a)*(b)*src[xf][yf+1] + (a)*(1-b)*src[xf+1][yf] + (a)*(b)*src[xf+1][yf+1]
         #Ival = src[xf][yf]
    return Ival

#Define path of src


#print(shape(src))
#Define centre
cenx = int(floor(shape(src)[0]/2))
ceny = int(floor(shape(src)[1]/2))
#Translation
theta = -4*pi/180

#Initialize tgt
tgt = np.zeros(shape(src))

for xn in range(0,len(tgt)) :
     for yn in range(0,len(tgt[0])) :
     
          #print("xn=",xn)
          tgt[xn][yn] = bilnr(src, theta, xn-cenx, yn-ceny)
          


#FINAL OUTPUT HAS A ROTATION OF 4 DEGREES ABOUT THE CENTRE COMPARED TO THE ORIGINAL IMAGE
plt.imshow(tgt,cmap = "gray")
plt.show()
#print(tgt)

# %%
def bilnr(src,tx, ty, xn, yn) :
     #Mapping to src grid
    x = xn-(ty)
    y = yn-(tx)
    xf = int(np.floor(x))
    yf = int(np.floor(y))

    #distance from pixel
    a = x-xf
    b = y-yf

    #Calculate intensity
    if xf >= np.shape(src)[0] or yf >=np.shape(src)[1] or xf<=0 or yf<= 0 :
         Ival = 0
    else :
         Ival = (1-a)*(1-b)*src[xf][yf] + (1-a)*(b)*src[xf][yf+1] + (a)*(1-b)*src[xf+1][yf] + (a)*(b)*src[xf+1][yf+1]

    return Ival

# %%
src = cv2.imread('lena_translate.png',0)
print(np.shape(src))
#cv2.imshow("Source",src)
#cv2.waitKey(0)
# Out:
# (256, 256)

# %%
tx = 3.75
ty = 4.3

# %%
for xn in range(0,len(tgt)) :
     for yn in range(0,len(tgt[0])) :
          tgt[xn][yn] = bilnr(src, tx, ty, xn, yn)
          

plt.imshow(tgt,cmap = "gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ABDULW~1\AppData\Local\Temp/ipykernel_15060/1387799831.py in <module>
# ----> 1 for xn in range(0,len(tgt)) :
#       2      for yn in range(0,len(tgt[0])) :
#       3           tgt[xn][yn] = bilnr(src, tx, ty, xn, yn)
#       4
#       5
#
# NameError: name 'tgt' is not defined
